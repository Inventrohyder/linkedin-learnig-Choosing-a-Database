# %% [markdown]
# # LinkedIn Learning: Choosing a Database: Postgres, MySQL, MongoDB, Cloud

# %% [markdown]
# ## Setup

# %%
from dotenv import load_dotenv
import os

# %%
# Load the environment secrets.
load_dotenv()
username = os.environ['USERNAME']
password = os.environ['PASSWORD']

# %%
# %load_ext sql

# %%
# Connect to the database
# %sql postgresql+psycopg2://$username:$password@localhost:5432/postgres

# %% [markdown]
# ### Database Setup

# %%
# Create the Database schema
# %sql CREATE SCHEMA new_postgres_connection
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# (psycopg2.errors.DuplicateSchema) schema "new_postgres_connection" already exists
#
# [SQL: CREATE SCHEMA new_postgres_connection]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %sql SET SCHEMA 'new_postgres_connection';
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# ## SQL

# %% [markdown]
# ### Create the tables

# %% [markdown]
# Create the tables externally, and add the data to the database too.

# %% [markdown]
# ### Create views

# %%
# %%sql
# -- create a view
# CREATE VIEW customer_and_orders AS
# SELECT *
# FROM customer c
#          JOIN
#         "Order" o ON o.customerId = c.id;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# Done.
# []

# %%
# %%sql
# -- check what's inside the view
# SELECT *
# FROM customer_and_orders;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 20 rows affected.
# [(119, 'Nonnah', 'Heaps', 'nheaps23@charter.com', '1(215)183-3228', '731 Forest Run Trail', 'Philadelphia', 'PA', 19184, 1000, '5/8/18', '$60.49 ', 'delivered', 119, 2),
#  (112, 'Lew', 'Lyddyard', 'llyddyard1c@leafandmortar.com', '1(267)770-5004', '1765 New Castle Place', 'Philadelphia', 'PA', 19120, 1001, '5/8/18', '$56.80 ', 'delivered', 112, 11),
#  (102, 'Torry', 'McKevitt', 'tmckevittg@gmail.com', '1(215)332-4420', '783 Boyd Court', 'Philadelphia', 'PA', 19191, 1002, '5/8/18', '$51.16 ', 'delivered', 102, 6),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'Philadelphia', 'PA', 19178, 1003, '5/8/18', '$53.55 ', 'cancelled', 109, 13),
#  (105, 'Perceval', 'Edscer', 'pedscerm@gmail.com', '1(215)131-3183', '078 Hudson Junction', 'Philadelphia', 'PA', 19125, 1004, '5/8/18', '$47.33 ', 'delivered', 105, 2),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'Philadelphia', 'PA', 19120, 1005, '5/8/18', '$50.57 ', 'delivered', 118, 13),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'Philadelphia', 'PA', 19125, 1006, '5/8/18', '$45.73 ', 'delivered', 107, 6),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'Philadelphia', 'PA', 19120, 1007, '5/8/18', '$56.17 ', 'cancelled', 118, 2),
#  (115, 'Jerrie', 'Clace', 'jclace1m@blogger.com', '1(215)108-9735', '7229 Riverside Drive', 'Philadelphia', 'PA', 19196, 1008, '5/8/18', '$40.76 ', 'delivered', 115, 6),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'Philadelphia', 'PA', 19196, 1009, '5/8/18', '$51.83 ', 'delivered', 101, 6),
#  (114, 'Clarence', 'Deppen', 'cdeppen1h@nih.gov', '1(215)411-8970', '62 Ruskin Center', 'Philadelphia', 'PA', 19136, 1010, '5/8/18', '$51.93 ', 'delivered', 114, 15),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'Philadelphia', 'PA', 19178, 1011, '5/8/18', '$44.63 ', 'delivered', 109, 15),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'Philadelphia', 'PA', 19178, 1012, '5/8/18', '$62.32 ', 'delivered', 100, 2),
#  (117, 'Emelia', 'Perillo', 'eperillo1t@yahoo.com', '1(267)345-4550', '412 Elka Parkway', 'Philadelphia', 'PA', 19115, 1013, '5/8/18', '$64.08 ', 'delivered', 117, 7),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'Philadelphia', 'PA', 19196, 1014, '5/9/18', '$53.78 ', 'delivered', 101, 10),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'Philadelphia', 'PA', 19178, 1015, '5/9/18', '$48.94 ', 'delivered', 100, 1),
#  (120, 'Chic', 'Harrinson', 'charrinson25@gmail.com', '1(215)429-9646', '5194 Forster Place', 'Philadelphia', 'PA', 19093, 1016, '5/9/18', '$48.75 ', 'delivered', 120, 10),
#  (108, 'Valeria', 'McMurraya', 'vmcmurraya12@gmail.com', '1(215)433-3544', '7 Mcguire Terrace', 'Philadelphia', 'PA', 19160, 1017, '5/9/18', '$46.58 ', 'out for de', 108, 2),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'Philadelphia', 'PA', 19125, 1018, '5/9/18', '$55.85 ', 'delivered', 107, 3),
#  (104, 'Lise', 'Searsby', 'lsearsbyk@gmail.com', '1(267)826-3556', '9193 Mendota Pass', 'Philadelphia', 'PA', 19151, 1019, '5/9/18', '$48.36 ', 'out for de', 104, 11)]

# %%
# %%sql
# -- create a materialized view
# CREATE MATERIALIZED VIEW customers_and_orders_mat AS
# SELECT *
# FROM customer c
# 	JOIN
# 	"Order" o ON o.customerId = c.id;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 20 rows affected.
# []

# %%
# %%sql
# -- check what's inside the materialized view
# SELECT *
# FROM customers_and_orders_mat;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 20 rows affected.
# [(119, 'Nonnah', 'Heaps', 'nheaps23@charter.com', '1(215)183-3228', '731 Forest Run Trail', 'Philadelphia', 'PA', 19184, 1000, '5/8/18', '$60.49 ', 'delivered', 119, 2),
#  (112, 'Lew', 'Lyddyard', 'llyddyard1c@leafandmortar.com', '1(267)770-5004', '1765 New Castle Place', 'Philadelphia', 'PA', 19120, 1001, '5/8/18', '$56.80 ', 'delivered', 112, 11),
#  (102, 'Torry', 'McKevitt', 'tmckevittg@gmail.com', '1(215)332-4420', '783 Boyd Court', 'Philadelphia', 'PA', 19191, 1002, '5/8/18', '$51.16 ', 'delivered', 102, 6),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'Philadelphia', 'PA', 19178, 1003, '5/8/18', '$53.55 ', 'cancelled', 109, 13),
#  (105, 'Perceval', 'Edscer', 'pedscerm@gmail.com', '1(215)131-3183', '078 Hudson Junction', 'Philadelphia', 'PA', 19125, 1004, '5/8/18', '$47.33 ', 'delivered', 105, 2),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'Philadelphia', 'PA', 19120, 1005, '5/8/18', '$50.57 ', 'delivered', 118, 13),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'Philadelphia', 'PA', 19125, 1006, '5/8/18', '$45.73 ', 'delivered', 107, 6),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'Philadelphia', 'PA', 19120, 1007, '5/8/18', '$56.17 ', 'cancelled', 118, 2),
#  (115, 'Jerrie', 'Clace', 'jclace1m@blogger.com', '1(215)108-9735', '7229 Riverside Drive', 'Philadelphia', 'PA', 19196, 1008, '5/8/18', '$40.76 ', 'delivered', 115, 6),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'Philadelphia', 'PA', 19196, 1009, '5/8/18', '$51.83 ', 'delivered', 101, 6),
#  (114, 'Clarence', 'Deppen', 'cdeppen1h@nih.gov', '1(215)411-8970', '62 Ruskin Center', 'Philadelphia', 'PA', 19136, 1010, '5/8/18', '$51.93 ', 'delivered', 114, 15),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'Philadelphia', 'PA', 19178, 1011, '5/8/18', '$44.63 ', 'delivered', 109, 15),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'Philadelphia', 'PA', 19178, 1012, '5/8/18', '$62.32 ', 'delivered', 100, 2),
#  (117, 'Emelia', 'Perillo', 'eperillo1t@yahoo.com', '1(267)345-4550', '412 Elka Parkway', 'Philadelphia', 'PA', 19115, 1013, '5/8/18', '$64.08 ', 'delivered', 117, 7),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'Philadelphia', 'PA', 19196, 1014, '5/9/18', '$53.78 ', 'delivered', 101, 10),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'Philadelphia', 'PA', 19178, 1015, '5/9/18', '$48.94 ', 'delivered', 100, 1),
#  (120, 'Chic', 'Harrinson', 'charrinson25@gmail.com', '1(215)429-9646', '5194 Forster Place', 'Philadelphia', 'PA', 19093, 1016, '5/9/18', '$48.75 ', 'delivered', 120, 10),
#  (108, 'Valeria', 'McMurraya', 'vmcmurraya12@gmail.com', '1(215)433-3544', '7 Mcguire Terrace', 'Philadelphia', 'PA', 19160, 1017, '5/9/18', '$46.58 ', 'out for de', 108, 2),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'Philadelphia', 'PA', 19125, 1018, '5/9/18', '$55.85 ', 'delivered', 107, 3),
#  (104, 'Lise', 'Searsby', 'lsearsbyk@gmail.com', '1(267)826-3556', '9193 Mendota Pass', 'Philadelphia', 'PA', 19151, 1019, '5/9/18', '$48.36 ', 'out for de', 104, 11)]

# %% [markdown]
# At this stage, both a normal `view` and a `materialized view` look the same.
# However, here comes the difference.

# %%
# %%sql
# -- The difference between a view and a materialized view
# -- update the customers table
# UPDATE customer
# SET city = 'New York'
# WHERE city = 'Philadelphia';
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 21 rows affected.
# []

# %%
# %%sql
# -- check inside the customers table
# SELECT *
# FROM customer;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 21 rows affected.
# [(100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'New York', 'PA', 19178),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'New York', 'PA', 19196),
#  (102, 'Torry', 'McKevitt', 'tmckevittg@gmail.com', '1(215)332-4420', '783 Boyd Court', 'New York', 'PA', 19191),
#  (103, 'Delinda', 'Andrioli', 'dandriolih@yahoo.com', '1(215)964-0847', '9788 Florence Terrace', 'New York', 'PA', 19172),
#  (104, 'Lise', 'Searsby', 'lsearsbyk@gmail.com', '1(267)826-3556', '9193 Mendota Pass', 'New York', 'PA', 19151),
#  (105, 'Perceval', 'Edscer', 'pedscerm@gmail.com', '1(215)131-3183', '078 Hudson Junction', 'New York', 'PA', 19125),
#  (106, 'Janice', 'Parman', 'jparmanv@aol.com', '1(215)718-2038', '43394 Crescent Oaks Terrace', 'New York', 'PA', 19093),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'New York', 'PA', 19125),
#  (108, 'Valeria', 'McMurraya', 'vmcmurraya12@gmail.com', '1(215)433-3544', '7 Mcguire Terrace', 'New York', 'PA', 19160),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'New York', 'PA', 19178),
#  (110, 'Fan', 'Tapenden', 'ftapenden14@ovcaa.org', '1(215)608-7546', '1 Loomis Circle', 'New York', 'PA', 19109),
#  (111, 'Meggy', 'Phipps', 'mphipps1b@gmail.com', '1(215)608-8575', '8171 Spenser Pass', 'New York', 'PA', 19141),
#  (112, 'Lew', 'Lyddyard', 'llyddyard1c@leafandmortar.com', '1(267)770-5004', '1765 New Castle Place', 'New York', 'PA', 19120),
#  (113, 'Caryn', 'Nozzolii', 'cnozzolii1d@yahoo.co.jp', '1(215)496-4061', '0 Russell Plaza', 'New York', 'PA', 19131),
#  (114, 'Clarence', 'Deppen', 'cdeppen1h@nih.gov', '1(215)411-8970', '62 Ruskin Center', 'New York', 'PA', 19136),
#  (115, 'Jerrie', 'Clace', 'jclace1m@blogger.com', '1(215)108-9735', '7229 Riverside Drive', 'New York', 'PA', 19196),
#  (116, 'Amalee', 'Copperwaite', 'acopperwaite1s@gmail.com', '1(215)776-9669', '5 East Hill', 'New York', 'PA', 19104),
#  (117, 'Emelia', 'Perillo', 'eperillo1t@yahoo.com', '1(267)345-4550', '412 Elka Parkway', 'New York', 'PA', 19115),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'New York', 'PA', 19120),
#  (119, 'Nonnah', 'Heaps', 'nheaps23@charter.com', '1(215)183-3228', '731 Forest Run Trail', 'New York', 'PA', 19184),
#  (120, 'Chic', 'Harrinson', 'charrinson25@gmail.com', '1(215)429-9646', '5194 Forster Place', 'New York', 'PA', 19093)]

# %% [markdown]
# If we check the materialized view, it would have the old data
# because it only runs once when it was created
# and the normal view runs the query everytime it is checked

# %%
# %%sql
# -- check what's inside the view
# SELECT *
# FROM customer_and_orders;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 20 rows affected.
# [(119, 'Nonnah', 'Heaps', 'nheaps23@charter.com', '1(215)183-3228', '731 Forest Run Trail', 'New York', 'PA', 19184, 1000, '5/8/18', '$60.49 ', 'delivered', 119, 2),
#  (112, 'Lew', 'Lyddyard', 'llyddyard1c@leafandmortar.com', '1(267)770-5004', '1765 New Castle Place', 'New York', 'PA', 19120, 1001, '5/8/18', '$56.80 ', 'delivered', 112, 11),
#  (102, 'Torry', 'McKevitt', 'tmckevittg@gmail.com', '1(215)332-4420', '783 Boyd Court', 'New York', 'PA', 19191, 1002, '5/8/18', '$51.16 ', 'delivered', 102, 6),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'New York', 'PA', 19178, 1003, '5/8/18', '$53.55 ', 'cancelled', 109, 13),
#  (105, 'Perceval', 'Edscer', 'pedscerm@gmail.com', '1(215)131-3183', '078 Hudson Junction', 'New York', 'PA', 19125, 1004, '5/8/18', '$47.33 ', 'delivered', 105, 2),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'New York', 'PA', 19120, 1005, '5/8/18', '$50.57 ', 'delivered', 118, 13),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'New York', 'PA', 19125, 1006, '5/8/18', '$45.73 ', 'delivered', 107, 6),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'New York', 'PA', 19120, 1007, '5/8/18', '$56.17 ', 'cancelled', 118, 2),
#  (115, 'Jerrie', 'Clace', 'jclace1m@blogger.com', '1(215)108-9735', '7229 Riverside Drive', 'New York', 'PA', 19196, 1008, '5/8/18', '$40.76 ', 'delivered', 115, 6),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'New York', 'PA', 19196, 1009, '5/8/18', '$51.83 ', 'delivered', 101, 6),
#  (114, 'Clarence', 'Deppen', 'cdeppen1h@nih.gov', '1(215)411-8970', '62 Ruskin Center', 'New York', 'PA', 19136, 1010, '5/8/18', '$51.93 ', 'delivered', 114, 15),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'New York', 'PA', 19178, 1011, '5/8/18', '$44.63 ', 'delivered', 109, 15),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'New York', 'PA', 19178, 1012, '5/8/18', '$62.32 ', 'delivered', 100, 2),
#  (117, 'Emelia', 'Perillo', 'eperillo1t@yahoo.com', '1(267)345-4550', '412 Elka Parkway', 'New York', 'PA', 19115, 1013, '5/8/18', '$64.08 ', 'delivered', 117, 7),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'New York', 'PA', 19196, 1014, '5/9/18', '$53.78 ', 'delivered', 101, 10),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'New York', 'PA', 19178, 1015, '5/9/18', '$48.94 ', 'delivered', 100, 1),
#  (120, 'Chic', 'Harrinson', 'charrinson25@gmail.com', '1(215)429-9646', '5194 Forster Place', 'New York', 'PA', 19093, 1016, '5/9/18', '$48.75 ', 'delivered', 120, 10),
#  (108, 'Valeria', 'McMurraya', 'vmcmurraya12@gmail.com', '1(215)433-3544', '7 Mcguire Terrace', 'New York', 'PA', 19160, 1017, '5/9/18', '$46.58 ', 'out for de', 108, 2),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'New York', 'PA', 19125, 1018, '5/9/18', '$55.85 ', 'delivered', 107, 3),
#  (104, 'Lise', 'Searsby', 'lsearsbyk@gmail.com', '1(267)826-3556', '9193 Mendota Pass', 'New York', 'PA', 19151, 1019, '5/9/18', '$48.36 ', 'out for de', 104, 11)]

# %%
# %%sql
# -- check what's inside the materialized view
# SELECT *
# FROM customers_and_orders_mat;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 20 rows affected.
# [(119, 'Nonnah', 'Heaps', 'nheaps23@charter.com', '1(215)183-3228', '731 Forest Run Trail', 'Philadelphia', 'PA', 19184, 1000, '5/8/18', '$60.49 ', 'delivered', 119, 2),
#  (112, 'Lew', 'Lyddyard', 'llyddyard1c@leafandmortar.com', '1(267)770-5004', '1765 New Castle Place', 'Philadelphia', 'PA', 19120, 1001, '5/8/18', '$56.80 ', 'delivered', 112, 11),
#  (102, 'Torry', 'McKevitt', 'tmckevittg@gmail.com', '1(215)332-4420', '783 Boyd Court', 'Philadelphia', 'PA', 19191, 1002, '5/8/18', '$51.16 ', 'delivered', 102, 6),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'Philadelphia', 'PA', 19178, 1003, '5/8/18', '$53.55 ', 'cancelled', 109, 13),
#  (105, 'Perceval', 'Edscer', 'pedscerm@gmail.com', '1(215)131-3183', '078 Hudson Junction', 'Philadelphia', 'PA', 19125, 1004, '5/8/18', '$47.33 ', 'delivered', 105, 2),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'Philadelphia', 'PA', 19120, 1005, '5/8/18', '$50.57 ', 'delivered', 118, 13),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'Philadelphia', 'PA', 19125, 1006, '5/8/18', '$45.73 ', 'delivered', 107, 6),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'Philadelphia', 'PA', 19120, 1007, '5/8/18', '$56.17 ', 'cancelled', 118, 2),
#  (115, 'Jerrie', 'Clace', 'jclace1m@blogger.com', '1(215)108-9735', '7229 Riverside Drive', 'Philadelphia', 'PA', 19196, 1008, '5/8/18', '$40.76 ', 'delivered', 115, 6),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'Philadelphia', 'PA', 19196, 1009, '5/8/18', '$51.83 ', 'delivered', 101, 6),
#  (114, 'Clarence', 'Deppen', 'cdeppen1h@nih.gov', '1(215)411-8970', '62 Ruskin Center', 'Philadelphia', 'PA', 19136, 1010, '5/8/18', '$51.93 ', 'delivered', 114, 15),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'Philadelphia', 'PA', 19178, 1011, '5/8/18', '$44.63 ', 'delivered', 109, 15),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'Philadelphia', 'PA', 19178, 1012, '5/8/18', '$62.32 ', 'delivered', 100, 2),
#  (117, 'Emelia', 'Perillo', 'eperillo1t@yahoo.com', '1(267)345-4550', '412 Elka Parkway', 'Philadelphia', 'PA', 19115, 1013, '5/8/18', '$64.08 ', 'delivered', 117, 7),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'Philadelphia', 'PA', 19196, 1014, '5/9/18', '$53.78 ', 'delivered', 101, 10),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'Philadelphia', 'PA', 19178, 1015, '5/9/18', '$48.94 ', 'delivered', 100, 1),
#  (120, 'Chic', 'Harrinson', 'charrinson25@gmail.com', '1(215)429-9646', '5194 Forster Place', 'Philadelphia', 'PA', 19093, 1016, '5/9/18', '$48.75 ', 'delivered', 120, 10),
#  (108, 'Valeria', 'McMurraya', 'vmcmurraya12@gmail.com', '1(215)433-3544', '7 Mcguire Terrace', 'Philadelphia', 'PA', 19160, 1017, '5/9/18', '$46.58 ', 'out for de', 108, 2),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'Philadelphia', 'PA', 19125, 1018, '5/9/18', '$55.85 ', 'delivered', 107, 3),
#  (104, 'Lise', 'Searsby', 'lsearsbyk@gmail.com', '1(267)826-3556', '9193 Mendota Pass', 'Philadelphia', 'PA', 19151, 1019, '5/9/18', '$48.36 ', 'out for de', 104, 11)]

# %%
# %%sql
# -- refresh materialized view
# REFRESH MATERIALIZED VIEW customers_and_orders_mat;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# Done.
# []

# %%
# %%sql
# -- check what's inside the materialized view
# SELECT *
# FROM customers_and_orders_mat;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 20 rows affected.
# [(119, 'Nonnah', 'Heaps', 'nheaps23@charter.com', '1(215)183-3228', '731 Forest Run Trail', 'New York', 'PA', 19184, 1000, '5/8/18', '$60.49 ', 'delivered', 119, 2),
#  (112, 'Lew', 'Lyddyard', 'llyddyard1c@leafandmortar.com', '1(267)770-5004', '1765 New Castle Place', 'New York', 'PA', 19120, 1001, '5/8/18', '$56.80 ', 'delivered', 112, 11),
#  (102, 'Torry', 'McKevitt', 'tmckevittg@gmail.com', '1(215)332-4420', '783 Boyd Court', 'New York', 'PA', 19191, 1002, '5/8/18', '$51.16 ', 'delivered', 102, 6),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'New York', 'PA', 19178, 1003, '5/8/18', '$53.55 ', 'cancelled', 109, 13),
#  (105, 'Perceval', 'Edscer', 'pedscerm@gmail.com', '1(215)131-3183', '078 Hudson Junction', 'New York', 'PA', 19125, 1004, '5/8/18', '$47.33 ', 'delivered', 105, 2),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'New York', 'PA', 19120, 1005, '5/8/18', '$50.57 ', 'delivered', 118, 13),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'New York', 'PA', 19125, 1006, '5/8/18', '$45.73 ', 'delivered', 107, 6),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'New York', 'PA', 19120, 1007, '5/8/18', '$56.17 ', 'cancelled', 118, 2),
#  (115, 'Jerrie', 'Clace', 'jclace1m@blogger.com', '1(215)108-9735', '7229 Riverside Drive', 'New York', 'PA', 19196, 1008, '5/8/18', '$40.76 ', 'delivered', 115, 6),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'New York', 'PA', 19196, 1009, '5/8/18', '$51.83 ', 'delivered', 101, 6),
#  (114, 'Clarence', 'Deppen', 'cdeppen1h@nih.gov', '1(215)411-8970', '62 Ruskin Center', 'New York', 'PA', 19136, 1010, '5/8/18', '$51.93 ', 'delivered', 114, 15),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'New York', 'PA', 19178, 1011, '5/8/18', '$44.63 ', 'delivered', 109, 15),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'New York', 'PA', 19178, 1012, '5/8/18', '$62.32 ', 'delivered', 100, 2),
#  (117, 'Emelia', 'Perillo', 'eperillo1t@yahoo.com', '1(267)345-4550', '412 Elka Parkway', 'New York', 'PA', 19115, 1013, '5/8/18', '$64.08 ', 'delivered', 117, 7),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'New York', 'PA', 19196, 1014, '5/9/18', '$53.78 ', 'delivered', 101, 10),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'New York', 'PA', 19178, 1015, '5/9/18', '$48.94 ', 'delivered', 100, 1),
#  (120, 'Chic', 'Harrinson', 'charrinson25@gmail.com', '1(215)429-9646', '5194 Forster Place', 'New York', 'PA', 19093, 1016, '5/9/18', '$48.75 ', 'delivered', 120, 10),
#  (108, 'Valeria', 'McMurraya', 'vmcmurraya12@gmail.com', '1(215)433-3544', '7 Mcguire Terrace', 'New York', 'PA', 19160, 1017, '5/9/18', '$46.58 ', 'out for de', 108, 2),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'New York', 'PA', 19125, 1018, '5/9/18', '$55.85 ', 'delivered', 107, 3),
#  (104, 'Lise', 'Searsby', 'lsearsbyk@gmail.com', '1(267)826-3556', '9193 Mendota Pass', 'New York', 'PA', 19151, 1019, '5/9/18', '$48.36 ', 'out for de', 104, 11)]

# %% [markdown]
# Refreshing a materialized view resnaps its data.

# %% [markdown]
# ### Postgres Functions

# %% [markdown]
# #### Fetch statement

# %%
# %%sql
# -- LIMIT is not considered SQL standard
# -- therefore Postgres allows both
# SELECT *
# FROM customer
# LIMIT 10;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 10 rows affected.
# [(100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'New York', 'PA', 19178),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'New York', 'PA', 19196),
#  (102, 'Torry', 'McKevitt', 'tmckevittg@gmail.com', '1(215)332-4420', '783 Boyd Court', 'New York', 'PA', 19191),
#  (103, 'Delinda', 'Andrioli', 'dandriolih@yahoo.com', '1(215)964-0847', '9788 Florence Terrace', 'New York', 'PA', 19172),
#  (104, 'Lise', 'Searsby', 'lsearsbyk@gmail.com', '1(267)826-3556', '9193 Mendota Pass', 'New York', 'PA', 19151),
#  (105, 'Perceval', 'Edscer', 'pedscerm@gmail.com', '1(215)131-3183', '078 Hudson Junction', 'New York', 'PA', 19125),
#  (106, 'Janice', 'Parman', 'jparmanv@aol.com', '1(215)718-2038', '43394 Crescent Oaks Terrace', 'New York', 'PA', 19093),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'New York', 'PA', 19125),
#  (108, 'Valeria', 'McMurraya', 'vmcmurraya12@gmail.com', '1(215)433-3544', '7 Mcguire Terrace', 'New York', 'PA', 19160),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'New York', 'PA', 19178)]

# %%
# %%sql
# SELECT *
# FROM customer
#     FETCH FIRST 10 ROWS ONLY;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 10 rows affected.
# [(100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'New York', 'PA', 19178),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'New York', 'PA', 19196),
#  (102, 'Torry', 'McKevitt', 'tmckevittg@gmail.com', '1(215)332-4420', '783 Boyd Court', 'New York', 'PA', 19191),
#  (103, 'Delinda', 'Andrioli', 'dandriolih@yahoo.com', '1(215)964-0847', '9788 Florence Terrace', 'New York', 'PA', 19172),
#  (104, 'Lise', 'Searsby', 'lsearsbyk@gmail.com', '1(267)826-3556', '9193 Mendota Pass', 'New York', 'PA', 19151),
#  (105, 'Perceval', 'Edscer', 'pedscerm@gmail.com', '1(215)131-3183', '078 Hudson Junction', 'New York', 'PA', 19125),
#  (106, 'Janice', 'Parman', 'jparmanv@aol.com', '1(215)718-2038', '43394 Crescent Oaks Terrace', 'New York', 'PA', 19093),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'New York', 'PA', 19125),
#  (108, 'Valeria', 'McMurraya', 'vmcmurraya12@gmail.com', '1(215)433-3544', '7 Mcguire Terrace', 'New York', 'PA', 19160),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'New York', 'PA', 19178)]

# %% [markdown]
# #### Intersect

# %%
# %%sql
# -- this is similar to the INNER JOIN
# SELECT DISTINCT c.id
# FROM customer c
#          JOIN "Order" o ON o.customerId = c.id;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 15 rows affected.
# [(101,),
#  (117,),
#  (114,),
#  (115,),
#  (102,),
#  (119,),
#  (108,),
#  (109,),
#  (112,),
#  (118,),
#  (105,),
#  (104,),
#  (120,),
#  (100,),
#  (107,)]

# %%
# %%sql
# SELECT id
# FROM customer
# INTERSECT
# SELECT customerID
# FROM "Order";
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 15 rows affected.
# [(101,),
#  (117,),
#  (115,),
#  (114,),
#  (119,),
#  (102,),
#  (112,),
#  (109,),
#  (108,),
#  (118,),
#  (105,),
#  (104,),
#  (120,),
#  (100,),
#  (107,)]

# %% [markdown]
# We don't require the `DISTINCT` keyword while using `INTERSECT`
# It is implied by `INTERSECT` and it chooses the values making
# them appear once

# %% [markdown]
# #### Full outer join

# %% [markdown]
# This is not supported by all DBMS(s)
# It returns all the rows from both tables

# %%
# %%sql
# SELECT *
# FROM customer c
#          FULL OUTER JOIN "Order" o
#                          ON o.customerId = c.id;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 26 rows affected.
# [(119, 'Nonnah', 'Heaps', 'nheaps23@charter.com', '1(215)183-3228', '731 Forest Run Trail', 'New York', 'PA', 19184, 1000, '5/8/18', '$60.49 ', 'delivered', 119, 2),
#  (112, 'Lew', 'Lyddyard', 'llyddyard1c@leafandmortar.com', '1(267)770-5004', '1765 New Castle Place', 'New York', 'PA', 19120, 1001, '5/8/18', '$56.80 ', 'delivered', 112, 11),
#  (102, 'Torry', 'McKevitt', 'tmckevittg@gmail.com', '1(215)332-4420', '783 Boyd Court', 'New York', 'PA', 19191, 1002, '5/8/18', '$51.16 ', 'delivered', 102, 6),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'New York', 'PA', 19178, 1003, '5/8/18', '$53.55 ', 'cancelled', 109, 13),
#  (105, 'Perceval', 'Edscer', 'pedscerm@gmail.com', '1(215)131-3183', '078 Hudson Junction', 'New York', 'PA', 19125, 1004, '5/8/18', '$47.33 ', 'delivered', 105, 2),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'New York', 'PA', 19120, 1005, '5/8/18', '$50.57 ', 'delivered', 118, 13),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'New York', 'PA', 19125, 1006, '5/8/18', '$45.73 ', 'delivered', 107, 6),
#  (118, 'Fletch', 'Rounce', 'frounce1z@kineteco.com', '1(267)173-3443', '243 Linden Way', 'New York', 'PA', 19120, 1007, '5/8/18', '$56.17 ', 'cancelled', 118, 2),
#  (115, 'Jerrie', 'Clace', 'jclace1m@blogger.com', '1(215)108-9735', '7229 Riverside Drive', 'New York', 'PA', 19196, 1008, '5/8/18', '$40.76 ', 'delivered', 115, 6),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'New York', 'PA', 19196, 1009, '5/8/18', '$51.83 ', 'delivered', 101, 6),
#  (114, 'Clarence', 'Deppen', 'cdeppen1h@nih.gov', '1(215)411-8970', '62 Ruskin Center', 'New York', 'PA', 19136, 1010, '5/8/18', '$51.93 ', 'delivered', 114, 15),
#  (109, 'Kirsten', 'Laugherane', 'klaugherane13@hplussport.com', '1(215)239-3665', '020 Susan Street', 'New York', 'PA', 19178, 1011, '5/8/18', '$44.63 ', 'delivered', 109, 15),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'New York', 'PA', 19178, 1012, '5/8/18', '$62.32 ', 'delivered', 100, 2),
#  (117, 'Emelia', 'Perillo', 'eperillo1t@yahoo.com', '1(267)345-4550', '412 Elka Parkway', 'New York', 'PA', 19115, 1013, '5/8/18', '$64.08 ', 'delivered', 117, 7),
#  (101, 'Isabeau', 'Fortie', 'ifortiea@gmail.com', '1(215)390-7974', '24493 Pepper Wood Terrace', 'New York', 'PA', 19196, 1014, '5/9/18', '$53.78 ', 'delivered', 101, 10),
#  (100, 'Teressa', 'Jordin', 'tjordin8@ovcaa.org', '1(215)950-6571', '1 South Road', 'New York', 'PA', 19178, 1015, '5/9/18', '$48.94 ', 'delivered', 100, 1),
#  (120, 'Chic', 'Harrinson', 'charrinson25@gmail.com', '1(215)429-9646', '5194 Forster Place', 'New York', 'PA', 19093, 1016, '5/9/18', '$48.75 ', 'delivered', 120, 10),
#  (108, 'Valeria', 'McMurraya', 'vmcmurraya12@gmail.com', '1(215)433-3544', '7 Mcguire Terrace', 'New York', 'PA', 19160, 1017, '5/9/18', '$46.58 ', 'out for de', 108, 2),
#  (107, 'Jill', 'MacConnell', 'jmacconnellw@yahoo.com', '1(215)832-2265', '37 Rusk Street', 'New York', 'PA', 19125, 1018, '5/9/18', '$55.85 ', 'delivered', 107, 3),
#  (104, 'Lise', 'Searsby', 'lsearsbyk@gmail.com', '1(267)826-3556', '9193 Mendota Pass', 'New York', 'PA', 19151, 1019, '5/9/18', '$48.36 ', 'out for de', 104, 11),
#  (106, 'Janice', 'Parman', 'jparmanv@aol.com', '1(215)718-2038', '43394 Crescent Oaks Terrace', 'New York', 'PA', 19093, None, None, None, None, None, None),
#  (113, 'Caryn', 'Nozzolii', 'cnozzolii1d@yahoo.co.jp', '1(215)496-4061', '0 Russell Plaza', 'New York', 'PA', 19131, None, None, None, None, None, None),
#  (110, 'Fan', 'Tapenden', 'ftapenden14@ovcaa.org', '1(215)608-7546', '1 Loomis Circle', 'New York', 'PA', 19109, None, None, None, None, None, None),
#  (116, 'Amalee', 'Copperwaite', 'acopperwaite1s@gmail.com', '1(215)776-9669', '5 East Hill', 'New York', 'PA', 19104, None, None, None, None, None, None),
#  (103, 'Delinda', 'Andrioli', 'dandriolih@yahoo.com', '1(215)964-0847', '9788 Florence Terrace', 'New York', 'PA', 19172, None, None, None, None, None, None),
#  (111, 'Meggy', 'Phipps', 'mphipps1b@gmail.com', '1(215)608-8575', '8171 Spenser Pass', 'New York', 'PA', 19141, None, None, None, None, None, None)]

# %% [markdown]
# #### Constraints

# %%
# %%sql
# -- Create a fake table
# CREATE TABLE christmas_products
# (
#     id        TEXT    NOT NULL,
#     price     INTEGER NOT NULL CHECK (price > 0), -- contraint
#     christmas BOOLEAN
# );
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# Insert values into christmas_products to see if constraint works

# %%
# %%sql
# -- This should work
# INSERT INTO christmas_products
# VALUES ('abc', 23, 'yes');
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 1 rows affected.
# []

# %%
# %%sql
# -- check if values insert into christmas_products
# SELECT *
# FROM christmas_products;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [('abc', 23, True)]

# %% [markdown]
# Test price constraint again in christmas products

# %%
# %%sql
# -- This should fail
# INSERT INTO christmas_products
# VALUES ('xyz', -1, 'yes');
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# ---------------------------------------------------------------------------
# CheckViolation                            Traceback (most recent call last)
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# CheckViolation: new row for relation "christmas_products" violates check constraint "christmas_products_price_check"
# DETAIL:  Failing row contains (xyz, -1, t).
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "-- This should fail\nINSERT INTO christmas_products\nVALUES ('xyz', -1, 'yes');\n")
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2347, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2345 with self.builtin_trap:
#    2346     args = (magic_arg_s, cell)
# -> 2347     result = fn(*args, **kwargs)
#    2348 return result
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sql/magic.py:217, in SqlMagic.execute(self, line, cell, local_ns)
#     214     return
#     216 try:
# --> 217     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     219     if (
#     220         result is not None
#     221         and not isinstance(result, str)
#    (...)
#     224         # Instead of returning values, set variables directly in the
#     225         # users namespace. Variable names given by column names
#     227         if self.autopandas:
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sql/run.py:367, in run(conn, sql, config, user_namespace)
#     365 else:
#     366     txt = sqlalchemy.sql.text(statement)
# --> 367     result = conn.session.execute(txt, user_namespace)
#     368 _commit(conn=conn, config=config)
#     369 if result and config.feedback:
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321 def _execute_on_connection(
#     322     self, connection, multiparams, params, execution_options, _force=False
#     323 ):
#     324     if _force or self.supports_execution:
# --> 325         return connection._execute_clauseelement(
#     326             self, multiparams, params, execution_options
#     327         )
#     328     else:
#     329         raise exc.ObjectNotExecutableError(self)
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1498, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486 compiled_cache = execution_options.get(
#    1487     "compiled_cache", self.engine._compiled_cache
#    1488 )
#    1490 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1491     dialect=dialect,
#    1492     compiled_cache=compiled_cache,
#    (...)
#    1496     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497 )
# -> 1498 ret = self._execute_context(
#    1499     dialect,
#    1500     dialect.execution_ctx_cls._init_compiled,
#    1501     compiled_sql,
#    1502     distilled_params,
#    1503     execution_options,
#    1504     compiled_sql,
#    1505     distilled_params,
#    1506     elem,
#    1507     extracted_params,
#    1508     cache_hit=cache_hit,
#    1509 )
#    1510 if has_events:
#    1511     self.dispatch.after_execute(
#    1512         self,
#    1513         elem,
#    (...)
#    1517         ret,
#    1518     )
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~/DataGripProjects/linkedin-learnnig-Choosing-a-Database/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.CheckViolation) new row for relation "christmas_products" violates check constraint "christmas_products_price_check"
# DETAIL:  Failing row contains (xyz, -1, t).
#
# [SQL: -- This should fail
# INSERT INTO christmas_products
# VALUES ('xyz', -1, 'yes');]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
# %%sql
# -- boolean test
# -- This should work
# INSERT INTO christmas_products
# VALUES ('abc', 23, true);
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# 1 rows affected.
# []

# %% [markdown]
# #### Cascade

# %% [markdown]
# You are able to drop everything that is dependent on that is referencing

# %%
# %%sql
# DROP TABLE christmas_products CASCADE;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/postgres
# Done.
# []
